# %% [markdown]
# *Integrantes*
#
# Felipe Mitsuo Takahashi Stephano RM570692
#
# Laura Godoy Callegari RM569181
#
# Letícia Araújo Espindola RM569308
#
# Mariana Dreset Carbollan 569207
#
# Milena de Aguiar Lopes Cardoso
# RM570599

# %% [markdown]
# # **Dataset 1 — Appliances Energy Prediction (UCI)**
#
# Situação
#
# Uma empresa de eficiência energética está analisando o comportamento de uma residência de baixo consumo. A equipe deseja identificar períodos de consumo elevado dos eletrodomésticos e observar quais condições de temperatura e umidade estavam presentes nesses momentos.

# %%
import pandas as pd

# %%
df1_ex1 = pd.read_csv("/content/dataset_ex_1.csv")

# %% [markdown]
# ![CP_04_ex_2_dataset.svg](data:image/svg+xml;base64,...)

# %%
# 1.	Carregue a amostra no Pandas e apresente head(), shape, info() e describe().
df1_ex1.head()
# Out:
#    Appliances  lights       T1     RH_1       T2     RH_2       T3     RH_3
# 0          40       0  20.8900  35.4000  17.7600  39.1633  20.2900  36.9000
# 1          90      10  21.8900  53.1000  21.2900  45.3600  21.6333  49.2267
# 2          50       0  21.3900  35.5000  17.6333  40.5300  21.6667  35.2000
# 3          50       0  21.3900  41.0333  23.8900  34.8400  22.0333  36.9333
# 4          70       0  19.9633  35.1267  16.4633  40.1267  20.0000  36.4000

# %%
df1_ex1.shape
# Out:
# (1974, 8)

# %%
df1_ex1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1974 entries, 0 to 1973
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Appliances  1974 non-null   int64
#  1   lights      1974 non-null   int64
#  2   T1          1974 non-null   float64
#  3   RH_1        1974 non-null   float64
#  4   T2          1974 non-null   float64
#  5   RH_2        1974 non-null   float64
#  6   T3          1974 non-null   float64
#  7   RH_3        1974 non-null   float64
# dtypes: float64(6), int64(2)
# memory usage: 123.5 KB

# %%
df1_ex1.columns
# Out:
# Index(['Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3'], dtype='object')

# %%
# 2. Renomeie Appliances para Consumo_Eletrodomesticos e simplifique
# o nome de pelo menos três atributos ambientais.
df1_ex1.rename(columns={'Appliances':'Consumo_Eletrodomesticos',
                    'T1': 'Temperatura_1',
                    'T2': 'Temperatura_2',
                    'T3': 'Temperatura_3',
                    }, inplace=True)

# %%
df1_ex1.head()
# Out:
#    Consumo_Eletrodomesticos  lights  Temperatura_1     RH_1  Temperatura_2  \
# 0                        40       0        20.8900  35.4000        17.7600
# 1                        90      10        21.8900  53.1000        21.2900
# 2                        50       0        21.3900  35.5000        17.6333
# 3                        50       0        21.3900  41.0333        23.8900
# 4                        70       0        19.9633  35.1267        16.4633
#
#       RH_2  Temperatura_3     RH_3
# 0  39.1633        20.2900  36.9000
# 1  45.3600        21.6333  49.2267
# 2  40.5300        21.6667  35.2000
# 3  34.8400        22.0333  36.9333
# 4  40.1267        20.0000  36.4000

# %%
# 3.	Determine o maior consumo de eletrodomésticos registrado na amostra.
df1_ex1['Consumo_Eletrodomesticos'].max()
print(f'O maior consumo de eletrodomésticos registrado na amostra é de {df1_ex1["Consumo_Eletrodomesticos"].max()}')
# Out:
# O maior consumo de eletrodomésticos registrado na amostra é de 770

# %%
# 4.	Calcule um limiar correspondente a 70% do valor máximo e
# crie um DataFrame contendo somente os registros acima desse limite.
limiar_70 = df1_ex1['Consumo_Eletrodomesticos'].max() * 0.7
df1_70_ex1 = df1_ex1[df1_ex1['Consumo_Eletrodomesticos'] > limiar_70]
df1_70_ex1.head()
# Out:
#      Consumo_Eletrodomesticos  lights  Temperatura_1     RH_1  Temperatura_2  \
# 352                       620       0        24.3900  44.3333        25.3700
# 427                       650       0        20.8900  36.7000        18.2900
# 453                       560      30        21.3567  36.0900        19.5667
# 616                       570      10        24.8900  32.6667        23.5600
# 696                       590      30        19.8567  47.6633        18.7000
#
#         RH_2  Temperatura_3     RH_3
# 352  37.7360        26.7300  38.8633
# 427  39.6633        21.2000  36.0000
# 453  37.1633        21.6333  35.0300
# 616  31.1400        23.6000  30.8233
# 696  34.1000        18.4267  37.8333

# %%
# 5.	Conte os registros selecionados e
# calcule qual percentual da amostra eles representam.
len(df1_70_ex1)
df1_ex1.shape[0]

percentual = len(df1_70_ex1) / len(df1_ex1) * 100
print(f'Percentual: {percentual:.2f}%')
# Out:
# Percentual: 1.11%

# %%
# 6.	Calcule a temperatura média de T1 e
# crie outro DataFrame contendo simultaneamente consumo acima de 70% do máximo e temperatura acima da média.
media = df1_ex1['Temperatura_1'].mean()
print(f'Temperatura média de T1: {media:.2f}')

df2_ex1 = df1_ex1[(df1_ex1['Temperatura_1'] > media) & (df1_ex1['Consumo_Eletrodomesticos'] > limiar_70)]
df2_ex1.head()
# Out:
# Temperatura média de T1: 21.66
#       Consumo_Eletrodomesticos  lights  Temperatura_1     RH_1  Temperatura_2  \
# 352                        620       0        24.3900  44.3333        25.3700
# 616                        570      10        24.8900  32.6667        23.5600
# 916                        750      30        22.4300  43.0000        21.9267
# 993                        690      10        22.5333  45.0267        22.0667
# 1182                       600      20        24.8900  48.1333        28.9175
#
#          RH_2  Temperatura_3     RH_3
# 352   37.7360          26.73  38.8633
# 616   31.1400          23.60  30.8233
# 916   40.1333          21.23  42.5967
# 993   39.7900          22.39  41.9300
# 1182  37.9475          27.10  42.4400

# %%
# 7.	Compare os dois DataFrames e
# explique o efeito da inclusão da temperatura como segundo critério.

print(df1_70_ex1.shape)
print(df2_ex1.shape)

# %% [markdown]
# A comparação entre os DataFrames df_70 e df2 mostra o seguinte:
#
# df_70 (apenas alto consumo): (22, 8)
# df2 (alto consumo e T1 alta): (8, 8)
# Como pode observar, a inclusão da temperatura como segundo critério reduziu o número de registros de 22 para 8. Isso significa que apenas 8 dos 22 registros de alto consumo também ocorreram quando a temperatura no ambiente 1 (T1) estava acima da média. Essa filtragem adicional é útil para identificar condições específicas que contribuem para o alto consumo e pode sugerir uma correlação entre consumo elevado e temperaturas mais altas. Este tipo de análise é valioso para a empresa de eficiência energética, pois pode indicar que o uso intensivo de eletrodomésticos está ligado a dias ou períodos mais quentes, possivelmente devido ao uso de ar condicionado ou outros equipamentos de refrigeração.

# %% [markdown]
# # **Dataset 2 — Steel Industry Energy Consumption (UCI)**
# Situação
#
# A equipe de gestão de energia de uma indústria siderúrgica deseja localizar situações de consumo elevado e verificar se esses períodos coincidem com condições de carga elevada ou valores menos favoráveis de fator de potência.

# %%
df1_ex2 = pd.read_csv("/content/dataset_ex_2.csv")

# %% [markdown]
# ![CP_04_ex_2_dataset.svg](data:image/svg+xml;base64,...)

# %%
# 1.	Carregue a amostra e renomeie Usage_kWh para Consumo_kWh, simplificando também os nomes dos atributos de fator de potência.
df1_ex2.rename(columns={'Usage_kWh':'Consumo_kWh',
                        'Lagging_Current_Reactive.Power_kVarh':'ER_Indutiva (kVarh)',
                        'Leading_Current_Reactive_Power_kVarh':'ER_Capacitiva (kVarh)',
                        'Lagging_Current_Power_Factor':'FP_com_corrente_atrasada',
                        'Leading_Current_Power_Factor': 'FP_capacitivo_adiantado'}, inplace=True)

# %%
# 2.	Apresente uma inspeção inicial com head(), shape, info() e describe().
df1_ex2.head()
# Out:
#    Consumo_kWh  ER_Indutiva (kVarh)  ER_Capacitiva (kVarh)  \
# 0         2.88                 3.82                    0.0
# 1        60.77                48.02                    0.0
# 2       120.42                59.65                    0.0
# 3         3.13                 0.00                   16.6
# 4        58.86                20.99                    0.0
#
#    FP_com_corrente_atrasada  FP_capacitivo_adiantado WeekStatus Day_of_week  \
# 0                     60.20                   100.00    Weekend      Sunday
# 1                     78.46                   100.00    Weekday    Thursday
# 2                     89.61                   100.00    Weekday      Friday
# 3                    100.00                    18.53    Weekend    Saturday
# 4                     94.19                   100.00    Weekday      Friday
#
#       Load_Type
# 0    Light_Load
# 1  Maximum_Load
# 2  Maximum_Load
# 3    Light_Load
# 4   Medium_Load

# %%
df1_ex2.shape
# Out:
# (7008, 8)

# %%
df1_ex2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7008 entries, 0 to 7007
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Consumo_kWh               7008 non-null   float64
#  1   ER_Indutiva (kVarh)       7008 non-null   float64
#  2   ER_Capacitiva (kVarh)     7008 non-null   float64
#  3   FP_com_corrente_atrasada  7008 non-null   float64
#  4   FP_capacitivo_adiantado   7008 non-null   float64
#  5   WeekStatus                7008 non-null   object
#  6   Day_of_week               7008 non-null   object
#  7   Load_Type                 7008 non-null   object
# dtypes: float64(5), object(3)
# memory usage: 438.1+ KB

# %%
df1_ex2.describe()
# Out:
#        Consumo_kWh  ER_Indutiva (kVarh)  ER_Capacitiva (kVarh)  \
# count  7008.000000          7008.000000            7008.000000
# mean     27.790164            13.206839               3.803711
# std      33.717719            16.444246               7.356412
# min       2.450000             0.000000               0.000000
# 25%       3.200000             2.380000               0.000000
# 50%       4.570000             5.040000               0.000000
# 75%      52.107500            22.977500               1.857500
# max     153.140000            87.700000              27.650000
#
#        FP_com_corrente_atrasada  FP_capacitivo_adiantado
# count               7008.000000              7008.000000
# mean                  80.672277                84.491448
# std                   18.869855                30.314798
# min                   37.870000                12.710000
# 25%                   63.602500                99.710000
# ...

# %%
 # 3.	Determine o maior consumo registrado
# e calcule um limiar de 75% do consumo máximo.
df1_ex2['Consumo_kWh'].max()
print(f'O maior consumo é: {df1_ex2['Consumo_kWh'].max()} kWh')
# Out:
# O maior consumo é: 153.14 kWh

# %%
limiar_75 = df1_ex2['Consumo_kWh'].max() * 0.75
print(f'O limiar de 75% do consumo máximo é: {limiar_75:.2f} kWh')
# Out:
# O limiar de 75% do consumo máximo é: 114.85 kWh

# %%
# 4.	Crie um DataFrame contendo os registros acima desse limiar
# e calcule a quantidade e o percentual de registros.
df2_75_ex2 = df1_ex2[df1_ex2['Consumo_kWh'] > limiar_75]
df2_75_ex2.head()
# Out:
#      Consumo_kWh  ER_Indutiva (kVarh)  ER_Capacitiva (kVarh)  \
# 2         120.42                59.65                    0.0
# 62        118.22                54.04                    0.0
# 100       129.13                46.58                    0.0
# 108       117.07                46.44                    0.0
# 159       139.57                58.90                    0.0
#
#      FP_com_corrente_atrasada  FP_capacitivo_adiantado WeekStatus Day_of_week  \
# 2                       89.61                    100.0    Weekday      Friday
# 62                      90.95                    100.0    Weekday    Thursday
# 100                     94.07                    100.0    Weekday      Monday
# 108                     92.95                    100.0    Weekday      Monday
# 159                     92.13                    100.0    Weekday    Thursday
#
#         Load_Type
# 2    Maximum_Load
# 62    Medium_Load
# 100   Medium_Load
# 108   Medium_Load
# 159  Maximum_Load

# %%
percentual2 = (len(df2_75_ex2) / len(df1_ex2)) * 100
print(f'O percentual de registros acima do limiar é: {percentual2:.2f}%')
# Out:
# O percentual de registros acima do limiar é: 1.84%

# %%
# 5.	Verifique quantos registros desse DataFrame pertencem à categoria Maximum Load.
df2_75_ex2[df2_75_ex2['Load_Type'] == 'Maximum_Load'].shape[0]
# Out:
# 62

# %%
# 6.	Escolha um dos atributos de fator de potência, observe seus valores e defina um limite coerente para representar valores mais baixos.

limiar_fator_potencia_baixo = 85
print(f'O limite escolhido para o fator de potência baixo (FP_com_corrente_atrasada) é: {limiar_fator_potencia_baixo:.2f} %')
# Out:
# O limite escolhido para o fator de potência baixo (FP_com_corrente_atrasada) é: 85.00 %

# %%
# 7 Crie um novo DataFrame contendo simultaneamente consumo elevado e fator de potência abaixo do limite escolhido.
df3_ex2 = df1_ex2[(df1_ex2['Consumo_kWh'] > limiar_75) & (df1_ex2['FP_com_corrente_atrasada'] < limiar_fator_potencia_baixo)]
df3_ex2.head()
# Out:
#       Consumo_kWh  ER_Indutiva (kVarh)  ER_Capacitiva (kVarh)  \
# 1968       125.28                80.46                    0.0
# 4990       123.77                79.63                    0.0
#
#       FP_com_corrente_atrasada  FP_capacitivo_adiantado WeekStatus  \
# 1968                     84.14                    100.0    Weekday
# 4990                     84.10                    100.0    Weekday
#
#      Day_of_week    Load_Type
# 1968     Tuesday  Medium_Load
# 4990   Wednesday   Light_Load

# %%
# 8.	Explique por que esse segundo conjunto de registros pode merecer maior atenção da equipe de energia.

# %% [markdown]
# A equipe de energia deve dedicar especial atenção aos registros contidos no `df3_ex2` devido à combinação de dois fatores cruciais que indicam um uso de energia potencialmente ineficiente:
#
# *   **Consumo Elevado (Consumo_kWh acima de 75% do valor máximo):** Este critério identifica períodos em que o consumo de energia da indústria é substancialmente alto. Um consumo elevado por si só já justifica uma análise para otimização e controle de gastos.
#
# *   **Fator de Potência Reduzido (FP_com_corrente_atrasada abaixo de 85%):** Um fator de potência abaixo do ideal significa que a energia elétrica não está sendo utilizada com máxima eficiência. Isso implica um consumo excessivo de energia reativa (que não contribui para o trabalho útil), resultando em:
#     *   **Custos Aumentados:** As distribuidoras de energia podem aplicar penalidades financeiras por um baixo fator de potência, somando-se ao custo do consumo energético elevado.
#     *   **Esforço Adicional da Infraestrutura:** Um fator de potência baixo exige que a rede elétrica transporte mais corrente para entregar a mesma quantidade de energia útil, o que pode sobrecarregar componentes como transformadores e cabos.
#     *   **Instabilidade na Tensão:** Pode ocorrer uma queda de tensão no sistema elétrico, comprometendo o desempenho de outros equipamentos.
#
# Ao focar nos dados do `df3_ex2`, a equipe pode investigar as causas dessa conjunção de alto consumo e baixo fator de potência. Por exemplo, pode-se identificar equipamentos que operam com menor eficiência, falhas em sistemas de correção do fator de potência ou processos industriais que naturalmente geram essas condições. Essa análise permite a implementação de ações corretivas pontuais, como manutenção preventiva, instalação ou ajuste de bancos de capacitores, ou otimização de procedimentos, visando a redução de custos e a melhoria geral da eficiência energética da instalação.

# %% [markdown]
# Dataset 3 — Power Consumption of Tetouan City (UCI)
#
# Situação
#
# Uma equipe responsável pelo planejamento da distribuição de energia em Tétouan deseja identificar qual das três zonas apresenta o maior pico de consumo e observar as condições ambientais registradas nos momentos de maior demanda.

# %% [markdown]
# ![foto_exc_3.svg](data:image/svg+xml;base64,...)

# %%
df3 = pd.read_csv('/content/exc_3.csv')

# %%
df3.head()
# Out:
#            DateTime  Temperature  Humidity  Wind Speed  \
# 0   4/18/2017 16:20        22.76     29.73       0.085
# 1  12/27/2017 17:10        15.92     54.44       0.085
# 2    1/2/2017 11:20        15.08     57.23       0.076
# 3   3/19/2017 20:20        12.42     72.30       0.081
# 4    4/24/2017 5:50        14.58     80.60       0.080
#
#    Zone 1 Power Consumption  Zone 2  Power Consumption  \
# 0               32985.14532                    19396.7
# 1               34737.64259                    29803.0
# 2               27894.68354                    20808.5
# 3               42476.93617                    23634.1
# 4               21341.14101                    12006.1
#
#    Zone 3  Power Consumption
# 0                    17623.3
# 1                    14417.3
# 2                    16458.8
# 3                    25089.7
# 4                    11531.6

# %%
df3.columns
# Out:
# Index(['DateTime', 'Temperature', 'Humidity', 'Wind Speed',
#        'Zone 1 Power Consumption', 'Zone 2  Power Consumption',
#        'Zone 3  Power Consumption'],
#       dtype='object')

# %%
df3=df3.drop(columns=['DateTime'])

# %%
df3.head()
# Out:
#    Temperature  Humidity  Wind Speed  Zone 1 Power Consumption  \
# 0        22.76     29.73       0.085               32985.14532
# 1        15.92     54.44       0.085               34737.64259
# 2        15.08     57.23       0.076               27894.68354
# 3        12.42     72.30       0.081               42476.93617
# 4        14.58     80.60       0.080               21341.14101
#
#    Zone 2  Power Consumption  Zone 3  Power Consumption
# 0                    19396.7                    17623.3
# 1                    29803.0                    14417.3
# 2                    20808.5                    16458.8
# 3                    23634.1                    25089.7
# 4                    12006.1                    11531.6

# %%
#Renomeie as três variáveis de consumo para Consumo_Zona_1, Consumo_Zona_2 e Consumo_Zona_3.
df3 = df3.rename(columns={'Zone 1 Power Consumption': 'Consumo_Zona_1', 'Zone 2  Power Consumption': 'Consumo_Zona_2', 'Zone 3  Power Consumption': 'Consumo_Zona_3'})

# %%
#Determine o consumo máximo registrado em cada uma das três zonas.
df3.max()
# Out:
# Temperature                     39.60000
# Humidity                        94.30000
# Wind Speed                       4.97800
# Zone 1 Power Consumption     50893.85128
# Zone 2  Power Consumption    36201.50000
# Zone 3  Power Consumption    47429.60000
# dtype: float64

# %%
#Identifique qual zona apresenta o maior pico de consumo na amostra.
print ('A zona 1 representa o maior pico de consumo')
# Out:
# A zona 1 representa o maior pico de consumo

# %%
#Para a zona identificada, calcule 70% do valor máximo e crie um DataFrame com os registros acima desse limiar.
limite = df3['Consumo_Zona_1'].max() * 0.7
print(limite)
# Out:
# 35625.695896

# %%
df4 = df3[df3['Consumo_Zona_1'] > limite]
print(df4)
# Out:
#       Temperature  Humidity  Wind Speed  Consumo_Zona_1  Consumo_Zona_2  \
# 3           12.42     72.30       0.081     42476.93617         23634.1
# 8           14.66     65.92       0.075     37286.69202         30716.2
# 12          21.03     86.50       0.068     40993.90728         25383.4
# 14          27.06     47.58       4.905     37475.16093         24276.2
# 19          19.20     65.81       4.924     40676.02649         24754.7
# ...           ...       ...         ...             ...             ...
# 1560        15.17     78.40       0.086     40942.96578         34306.2
# 1565        28.95     40.85       4.935     37206.82713         23653.9
# 1568        25.25     39.65       4.918     46232.92035         26128.1
# 1569        28.28     72.00       4.916     36524.65116         22625.3
# 1572        27.59     56.45       0.072     47362.12625         31336.7
#
#       Consumo_Zona_3
# 3            25089.7
# 8            15834.8
# 12           24960.0
# ...

# %%
#Conte os registros e calcule o percentual que eles representam.
len (df4)
# Out:
# 496

# %%
(len (df4)) / len (df3) * 100
# Out:
# 31.532104259376986

# %%
quantidade = len (df4)
porcentagem = (len (df4)) / len (df3) * 100

print("Quantidade de registros:", quantidade)
print("Porcentagem:", porcentagem, "%")
# Out:
# Quantidade de registros: 496
# Porcentagem: 31.532104259376986 %

# %%
#Calcule a temperatura média e crie um segundo DataFrame contendo consumo acima do limiar e temperatura acima da média.
media_temperatura = df3['Temperature'].mean()
print(media_temperatura)
# Out:
# 18.689275905912268

# %%
df_temp = df3[df3['Consumo_Zona_1'] > limite]
df_resposta = df_temp[df_temp['Temperature'] > media_temperatura]
print(df_temp)
print(df_resposta)
# Out:
#       Temperature  Humidity  Wind Speed  Consumo_Zona_1  Consumo_Zona_2  \
# 3           12.42     72.30       0.081     42476.93617         23634.1
# 8           14.66     65.92       0.075     37286.69202         30716.2
# 12          21.03     86.50       0.068     40993.90728         25383.4
# 14          27.06     47.58       4.905     37475.16093         24276.2
# 19          19.20     65.81       4.924     40676.02649         24754.7
# ...           ...       ...         ...             ...             ...
# 1560        15.17     78.40       0.086     40942.96578         34306.2
# 1565        28.95     40.85       4.935     37206.82713         23653.9
# 1568        25.25     39.65       4.918     46232.92035         26128.1
# 1569        28.28     72.00       4.916     36524.65116         22625.3
# 1572        27.59     56.45       0.072     47362.12625         31336.7
#
#       Consumo_Zona_3
# 3            25089.7
# 8            15834.8
# 12           24960.0
# ...

# %%
#Compare os dois conjuntos e explique o que ocorreu com a quantidade de registros após a inclusão da condição ambiental.
print("Registros antes:", len(df4))
print("Registros depois:", len(df_temp))
print("Registros depois:", len(df_resposta))
# Out:
# Registros antes: 496
# Registros depois: 496
# Registros depois: 346

# %% [markdown]
# *Ao incluir a condição de temperatura acima da média, a quantidade de registros diminuiu. Isso aconteceu porque, além de apresentar consumo acima de 70% do pico da Zona 1, o registro também precisava apresentar temperatura acima da média.*

# %% [markdown]
# # **Dataset 4 - Solar Power Generation Data**
#
# **Situação**
#
# Uma equipe de operação de uma usina fotovoltaica deseja localizar períodos de alta geração e identificar quais inversores aparecem com maior frequência nesses momentos. Nesta atividade, o foco inicial será o arquivo de geração da planta, sem realizar junção com o arquivo de sensores.

# %% [markdown]
# ![fotooods4.svg](data:image/svg+xml;base64,...)

# %%
# carregar a amostra
df5 = pd.read_csv('/content/Plant_1_Generation_Data.csv')

# %%
# renomear as colunas
df5 = df5.rename(columns={'DATE_TIME': 'DATA_HORA',
                           'PLANT_ID': 'ID_PLANTA',
                           'SOURCE_KEY': 'ID_INVERSOR',
                           'DC_POWER': 'POTENCIA_CC',
                           'AC_POWER': 'POTENCIA_CA',
                           'DAILY_YIELD': 'GERACAO_DIARIA',
                           'TOTAL_YIELD': 'GERACAO_TOTAL'
                           })

# %%
# visualização
df5.head()
# Out:
#           DATA_HORA  ID_PLANTA      ID_INVERSOR  POTENCIA_CC  POTENCIA_CA  \
# 0  15-05-2020 00:00    4135001  1BY6WEcLGh8j5v7          0.0          0.0
# 1  15-05-2020 00:00    4135001  1IF53ai7Xc0U56Y          0.0          0.0
# 2  15-05-2020 00:00    4135001  3PZuoBAID5Wc2HD          0.0          0.0
# 3  15-05-2020 00:00    4135001  7JYdWkrLSPkdwr4          0.0          0.0
# 4  15-05-2020 00:00    4135001  McdE0feGgRqW7Ca          0.0          0.0
#
#    GERACAO_DIARIA  GERACAO_TOTAL
# 0             0.0      6259559.0
# 1             0.0      6183645.0
# 2             0.0      6987759.0
# 3             0.0      7602960.0
# 4             0.0      7158964.0

# %%
# dimensões do dataframe
df5.shape
# Out:
# (68778, 7)

# %%
# informações dos atributos
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68778 entries, 0 to 68777
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   DATA_HORA       68778 non-null  object
#  1   ID_PLANTA       68778 non-null  int64
#  2   ID_INVERSOR     68778 non-null  object
#  3   POTENCIA_CC     68778 non-null  float64
#  4   POTENCIA_CA     68778 non-null  float64
#  5   GERACAO_DIARIA  68778 non-null  float64
#  6   GERACAO_TOTAL   68778 non-null  float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 3.7+ MB

# %%
# estatísticas descritivas dos atributos
df5.describe()
# Out:
#        ID_PLANTA   POTENCIA_CC   POTENCIA_CA  GERACAO_DIARIA  GERACAO_TOTAL
# count    68778.0  68778.000000  68778.000000    68778.000000   6.877800e+04
# mean   4135001.0   3147.426211    307.802752     3295.968737   6.978712e+06
# std          0.0   4036.457169    394.396439     3145.178309   4.162720e+05
# min    4135001.0      0.000000      0.000000        0.000000   6.183645e+06
# 25%    4135001.0      0.000000      0.000000        0.000000   6.512003e+06
# 50%    4135001.0    429.000000     41.493750     2658.714286   7.146685e+06
# 75%    4135001.0   6366.964286    623.618750     6274.000000   7.268706e+06
# max    4135001.0  14471.125000   1410.950000     9163.000000   7.846821e+06

# %%
# o valor máximo da potência CA
PMAX = df5['POTENCIA_CA'].max()
print(f'O valor máximo da potência CA é: {PMAX:.3f} kW')
# Out:
# O valor máximo da potência CA é: 1410.950 kW

# %%
# limiar de 70% da potência ativa
P70 = PMAX * 0.70
print(f'O valor do limiar de 70% da potência CA é: {P70:.3f} kW')
# Out:
# O valor do limiar de 70% da potência CA é: 987.665 kW

# %%
# dataframe com registros acima desse limite
df5_2 = df5[df5['POTENCIA_CA'] > P70]
df5_2.head()
# Out:
#             DATA_HORA  ID_PLANTA      ID_INVERSOR  POTENCIA_CC  POTENCIA_CA  \
# 952  15-05-2020 11:00    4135001  McdE0feGgRqW7Ca  10257.85714  1001.385714
# 960  15-05-2020 11:00    4135001  iCRJl6heRkivqQ3  10353.00000  1010.628571
# 963  15-05-2020 11:00    4135001  rGa61gmuvPhdLxV  10648.85714  1039.528571
# 965  15-05-2020 11:00    4135001  uHbuxQJl8lW7ozc  10481.14286  1023.128571
# 969  15-05-2020 11:00    4135001  zVJPv84UY57bAof  10284.28571  1004.314286
#
#      GERACAO_DIARIA  GERACAO_TOTAL
# 952     2107.571429    7161071.571
# 960     2092.714286    7180084.714
# 963     2089.285714    7113582.286
# 965     2124.571429    7040805.571
# 969     1689.285714    7117840.286

# %%
# quantidade e percentual
qtd = len(df5_2)
percentual = (qtd / len(df5)) * 100
print(f'a quantidade de registros é de {qtd}')
print(f'o percentual de registros é de {percentual:.2f}%')
# Out:
# a quantidade de registros é de 5996
# o percentual de registros é de 8.72%

# %%
# frequência dos inversores
frequencia = df5_2['ID_INVERSOR'].value_counts()
print(f'a frequencia é de {frequencia}')
# Out:
# a frequencia é de ID_INVERSOR
# adLQvlD726eNBSB    310
# McdE0feGgRqW7Ca    301
# ZnxXDlPa8U1GXgE    298
# 1IF53ai7Xc0U56Y    296
# VHMLBKoKgIrUVDU    291
# iCRJl6heRkivqQ3    289
# zVJPv84UY57bAof    289
# wCURE6d3bPkepu2    288
# 3PZuoBAID5Wc2HD    285
# uHbuxQJl8lW7ozc    280
# pkci93gMrogZuBj    278
# YxYtjZvoooNbGkE    277
# zBIq5rxdHJRwDNY    276
# sjndEbLyjtCKgGv    276
# z9Y9gH1T5YWrNuG    271
# rGa61gmuvPhdLxV    269
# ZoEaEvLYb1n2sOq    263
# WRmjgnKYAwPKWDb    261
# 7JYdWkrLSPkdwr4    259
# ih0vzX44oOqAx2f    254
# 1BY6WEcLGh8j5v7    201
# bvBOhCH3iADSZry    184
# Name: count, dtype: int64

# %%
# inversor mais frequente
maiorfreq_inversor = frequencia.idxmax()
maior_freq = frequencia.max()
print(f'o inversor com maior frequencia é o {maiorfreq_inversor}, com {maior_freq} registros')

# o inversor adLQvlD726eNBSB foi o que mais apareceyu nos registros de alta geração, totalizando 310 ocorrências.
# esse resultado indica apenas que ele esteve presente mais vezes nesse recorte de dados;
# não sendo suficiente para concluir que possui melhor desempenho ou que os demais apresentam falhas.
# Out:
# o inversor com maior frequencia é o adLQvlD726eNBSB, com 310 registros

# %% [markdown]
# # Dataset 5 — Wind & Solar Energy Production (Kaggle)
#
# Situação
#
# Um operador de um portfólio de fontes renováveis deseja comparar a ocorrência de períodos de alta produção solar e alta produção eólica. Como as duas fontes possuem escalas próprias, cada uma deverá ser comparada com o seu próprio valor máximo

# %% [markdown]
# ![Screenshot 2026-08-24 104423.png](data:image/png;base64,...)

# %%
df = pd.read_csv('/content/Energy_Production_2.csv')
df.head()
# Out:
#   Source  Season  Production
# 0   Wind  Winter       11400
# 1   Wind  Winter        7917
# 2  Solar  Summer        8835
# 3   Wind    Fall         989
# 4   Wind  Winter       12526

# %%
# 1.	Renomeie as variáveis principais para Geracao_Solar e Geracao_Eolica.
df.rename(columns={'Solar': 'Geracao_Solar', 'Wind': 'Geracao_Eolica'}, inplace=True)
df.head()

# %%
# 2.	Determine o valor máximo registrado para cada fonte.
max_solar_production = df[df['Source'] == 'Solar']['Production'].max()
max_wind_production = df[df['Source'] == 'Wind']['Production'].max()

print(f"Maximum Solar Production: {max_solar_production}")
print(f"Maximum Wind Production: {max_wind_production}")

# %%
# 3. Calcule separadamente 70% do máximo solar e 70% do máximo eólico.

P70_solar = 0.70 * max_solar_production
df_alto_solar = df[(df['Source'] == 'Solar') & (df['Production'] > P70_solar)]

P70_wind = 0.70 * max_wind_production
df_alto_wind = df[(df['Source'] == 'Wind') & (df['Production'] > P70_wind)]

print(f"70% do máximo solar: {P70_solar}")
print(f"Registros de produção solar acima de 70%: {len(df_alto_solar)}")
print(f"70% do máximo eólico: {P70_wind}")
print(f"Registros de produção eólica acima de 70%: {len(df_alto_wind)}")

# %%
# 4. Crie um DataFrame para registros de alta geração solar e outro para registros de alta geração eólica.
df_alto_solar = df[(df['Source'] == 'Solar') & (df['Production'] > P70_solar)]
df_alto_wind = df[(df['Source'] == 'Wind') & (df['Production'] > P70_wind)]

df2 = pd.concat([df_alto_solar, df_alto_wind])
df2

# %%
# 5.	Conte os registros de cada DataFrame e calcule seus respectivos percentuais.
total = len(df2)
total2 = len(df)

print(f"Total de registros: {total}")
print(f"Total de registros: {total2}")

# %%
percentual = total / total2 * 100
print(f'Percentual: {percentual:.2f}%')

# %%
# 6.	Compare qual fonte aparece com maior frequência acima de 70% do seu próprio máximo.
perc_solar = (qtd_solar / len(solar)) * 100
perc_eolica = (qtd_eolica / len(eolica)) * 100

print("\nAlta geração solar:")
print("Quantidade:", qtd_solar)
print("Percentual:", round(perc_solar, 2), "%")

print("\nAlta geração eólica:")
print("Quantidade:", qtd_eolica)
print("Percentual:", round(perc_eolica, 2), "%")

# Comparação
if perc_solar > perc_eolica:
    print("\nA energia solar aparece com maior frequência acima de 70% do máximo.")
elif perc_eolica > perc_solar:
    print("\nA energia eólica aparece com maior frequência acima de 70% do máximo.")
else:
    print("\nAs duas fontes possuem a mesma frequência.")

# %% [markdown]
#  # 7.	Explique por que não seria adequado utilizar diretamente o mesmo valor numérico de potência como limite para as duas fontes sem antes observar a escala de cada variável.
#  Não seria adequado usar o mesmo valor numérico absoluto de potência como limite para as produções solar e eólica sem antes observar a escala de cada uma, e aqui está o porquê:
#
# Diferença Inerente de Escala: Como vimos nos dados, a produção máxima de energia solar é de 16316 e a produção máxima de energia eólica é de 22929. Estas são escalas diferentes. Um valor limite de, digamos, 15000 unidades de energia, representaria uma proporção muito diferente do máximo para cada fonte.
#
# Viés e Comparação Injusta: Se usássemos um limite fixo, estaríamos impondo uma régua que pode ser desproporcional. Por exemplo:
#
# Um limite de 15000 para a energia solar seria um patamar muito alto (quase 92% do seu máximo), resultando em poucos registros de "alta geração".
# Para a energia eólica, 15000 seria um patamar mais baixo (cerca de 65% do seu máximo), o que significaria mais registros de "alta geração" apenas porque seu potencial máximo é maior.
# Análise Distorcida: Isso levaria a conclusões distorcidas sobre qual fonte de energia tem maior frequência de "alta geração". Estaríamos comparando maçãs com laranjas, em vez de comparar o desempenho de cada fruta em relação ao seu próprio potencial.
#
# É por isso que, no notebook, calculamos 70% do máximo de cada fonte individualmente (P70_solar e P70_wind). Essa abordagem respeita a escala de cada tipo de energia, permitindo uma comparação justa e significativa do desempenho de ambas em relação aos seus próprios limites operacionais.

# %% [markdown]
# # **Dataset 6 - Individual Household Electric Power Consumption**
#
# **Situação**
#
# Uma residência possui monitoramento elétrico detalhado e deseja identificar episódios de demanda elevada que também apresentem corrente acima do comportamento médio. O dataset é o mesmo utilizado como referência em aula, mas o critério de análise será diferente.

# %% [markdown]
# ![fotinho_individualhousehold.svg](data:image/svg+xml;base64,...)

# %%
# ncarregar a amostra
df6 = pd.read_csv('/content/individual_household 1.csv')
df6.head()
# Out:
#                   Date                 Time  Global_active_power  \
# 0  2008-12-01 00:00:00  2026-08-19 09:44:00                1.502
# 1  2006-12-17 00:00:00  2026-08-19 23:39:00                0.374
# 2  2009-06-03 00:00:00  2026-08-19 17:01:00                0.620
# 3  2007-05-09 00:00:00  2026-08-19 05:53:00                0.280
# 4  2008-12-14 00:00:00  2026-08-19 02:57:00                1.372
#
#    Global_reactive_power  Voltage  Global_intensity  Sub_metering_1  \
# 0                  0.074   240.17               6.4               0
# 1                  0.264   245.50               1.8               0
# 2                  0.300   239.85               3.0               0
# 3                  0.200   235.72               1.4               0
# 4                  0.054   243.95               5.6               0
#
#    Sub_metering_2  Sub_metering_3
# 0               0              18
# 1               2               0
# 2               1               1
# ...

# %%
# renomear as colunas
df6 = df6.rename(columns={'Date': 'Data',
                           'Time': 'Hora',
                           'Global_active_power': 'Potencia_ativa',
                           'Global_reactive_power': 'Potencia_reativa',
                           'Voltage': 'Tensao',
                           'Global_intensity': 'Corrente',
                           'Sub_metering_1': 'Sub_1',
                           'Sub_metering_2': 'Sub_2',
                           'Sub_metering_3': 'Sub_3',
                           })
df6.head()
# Out:
#                   Data                 Hora  Potencia_ativa  Potencia_reativa  \
# 0  2008-12-01 00:00:00  2026-08-19 09:44:00           1.502             0.074
# 1  2006-12-17 00:00:00  2026-08-19 23:39:00           0.374             0.264
# 2  2009-06-03 00:00:00  2026-08-19 17:01:00           0.620             0.300
# 3  2007-05-09 00:00:00  2026-08-19 05:53:00           0.280             0.200
# 4  2008-12-14 00:00:00  2026-08-19 02:57:00           1.372             0.054
#
#    Tensao  Corrente  Sub_1  Sub_2  Sub_3
# 0  240.17       6.4      0      0     18
# 1  245.50       1.8      0      2      0
# 2  239.85       3.0      0      1      1
# 3  235.72       1.4      0      0      0
# 4  243.95       5.6      0      0     18

# %%
# valor máximo da potência ativa
potmax = df6['Potencia_ativa'].max()
print(f'o valor máximo da potência ativa é: {potmax:.2f}KW')
# Out:
# o valor máximo da potência ativa é: 10.54KW

# %%
# 75% do valor máximo
limite = potmax * 0.75
print(f'o limite de 75% é: {limite:.3f}')
# Out:
# o limite de 75% é: 7.902

# %%
# dataframe com os registros cuja potencia ativa seja maior que 7.902
df_alta = df6[df6['Potencia_ativa'] > limite ]
df_alta.head()
# Out:
#                       Data                 Hora  Potencia_ativa  \
# 3132   2009-01-24 00:00:00  2026-08-19 13:01:00           8.540
# 3630   2007-01-09 00:00:00  2026-08-19 20:52:00           8.278
# 10339  2010-11-04 00:00:00  2026-08-19 08:33:00           8.026
# 11695  2007-04-05 00:00:00  2026-08-19 21:00:00           8.102
# 27983  2008-10-19 00:00:00  2026-08-19 01:24:00          10.290
#
#        Potencia_reativa  Tensao  Corrente  Sub_1  Sub_2  Sub_3
# 3132              0.238  236.23      36.0     80     35     17
# 3630              0.088  231.50      35.6      0     71     17
# 10339             0.066  236.45      33.8     37     73     18
# 11695             0.190  229.31      35.4     35     35     17
# 27983             0.302  230.90      44.6     35     66     17

# %%
# quantidade e percentual de registros selecionados
quantidade = len(df_alta)
percentual = (quantidade / len(df6)) * 100
print(f'a quantidade de registros é {quantidade}')
print(f'o percentual de registros é {percentual:.3f}%')
# Out:
# a quantidade de registros é 58
# o percentual de registros é 0.028%

# %%
# corrente média da amostra
corrente_media = df6['Corrente'].mean()
print(f'a corrente média é {corrente_media:.2f}A')
# Out:
# a corrente média é 4.63A

# %%
# outro dataframe contendo simultaneamente potência ativa acima de 75% do máximo e corrente acima da média
df7_alta_corrente = df6[(df6['Potencia_ativa'] > limite) & (df6['Corrente'] > corrente_media)]
df7_alta_corrente.head()
# Out:
#                       Data                 Hora  Potencia_ativa  \
# 3132   2009-01-24 00:00:00  2026-08-19 13:01:00           8.540
# 3630   2007-01-09 00:00:00  2026-08-19 20:52:00           8.278
# 10339  2010-11-04 00:00:00  2026-08-19 08:33:00           8.026
# 11695  2007-04-05 00:00:00  2026-08-19 21:00:00           8.102
# 27983  2008-10-19 00:00:00  2026-08-19 01:24:00          10.290
#
#        Potencia_reativa  Tensao  Corrente  Sub_1  Sub_2  Sub_3
# 3132              0.238  236.23      36.0     80     35     17
# 3630              0.088  231.50      35.6      0     71     17
# 10339             0.066  236.45      33.8     37     73     18
# 11695             0.190  229.31      35.4     35     35     17
# 27983             0.302  230.90      44.6     35     66     17

# %%
# comparando os dois conjuntos
print(f'registros apenas com alta potencia: {len(df_alta)}')
print(f'registros com alta potencia e corrente acima da média: {len(df7_alta_corrente)}')
# Out:
# registros apenas com alta potencia: 58
# registros com alta potencia e corrente acima da média: 58

# %%
# ou seja, a inclusão da corrente acima da média como segunda condição não alterou a quantidade de registros selecionados.
# os dois dataframes possuem 58 registros.
# isso indica que todos os registros com potencia ativa acima de 75% do valor maximo tambem apresentam corrente acima da media da amostra
